# %% [markdown]
# # Zdarzenia i prawdopodobieńswto

# %% [markdown]
# ## ZAD. 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A = [1,2]
B = [1,2,3]

C = (A[1] or A[2]) and ((B[1] and B[2]) or (B[1] and B[3]) or [B[2] and B[3]])
print(C)
# Out:
# 3

# %% [markdown]
# ## ZAD. 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A = ["Reszka","Orzeł"]

def P(n_rzutow, n_orlow):
    from math import comb
    p = 1/2
    q = 1 - p
    return comb(n_rzutow, n_orlow) * (p**n_orlow) * (q**(n_rzutow - n_orlow))

# P(X >= 2) = P(X=2) + P(X=3)

print(P(3,2) + P(3,3))
# Out:
# 0.5

# %% [markdown]
# ## ZAD. 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
N = 52 * 51 * 50
print(f"{N} możliwych ułożeń 3 kart")
prob = 1/52 * 4/51
print(f"{prob * 100}%")
# Out:
# 132600 możliwych ułożeń 3 kart
# 0.1508295625942685%

# %% [markdown]
# ## ZAD. 4

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## 1
# Możliwe pary: 
# (C, C)
# (C, D)
# (D, C)
# (D, D)

# Bierzemy pod  uwagę tylko pary (C, C) i (C, D)
# P((C, C) | (C, *)) = P(C, C) / (P(C, C) + P(C, D)) = 1/4 / (1/4 + 1/4) = 1/2

# %%
## 2
# Bierzemy pod uwagę tylko pary B = (C, C), (C, D) i (D, C)
# P((C, C) | B) = P(C, C) / (P(C, C) + P(C, D) + P(D, C)) = 1/4 / (1/4 + 1/4 + 1/4) = 1/3

# %% [markdown]
# ## ZAD. 5

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Prawdopodobieństwo że bląd w 1 sprawdzaniu = 0.08
# Prawdopodobieństwo że bląd w 2 sprawdzaniu = 0.05
# Prawdopodobieństwo że bląd w sprzawdzaniu = 0.08 * 0.05 = 0.004

# %% [markdown]
# ## ZAD. 6

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 60% = 0.6
# 70% = 0.7

# P(niewykrycia 1) = 1 - 0.6 = 0.4
# P(niewykrycia 2) = 1 - 0.7 = 0.3
# P(niewykrycia 3) = 1 - 0.7 = 0.3
# P(niewykrycia) = 0.4 * 0.3 * 0.3 = 0.036
# P(wykrycia) = 1 - 0.036 = 0.964 = 96.4%

# %% [markdown]
# ## ZAD. 7

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Prawdopodobieństwo że 2 kula będzie biała 

# Pierwsza kula biała => P(A) = b/(b+c) * (b-1)/(b+c-1)
# Pierwsza kula czarna => P(B) = c/(b+c) * b/(b+c-1)

# P(A or B) = P(A) + P(B) = b/(b+c) * (b-1)/(b+c-1) + c/(b+c) * b/(b+c-1)
# = ( b(b-1) + cb )/((b+c)(b+c-1)) = b(b+c-1)/((b+c)(b+c-1)) = b/(b+c)

# %% [markdown]
# ## ZAD. 8

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## A)
# Prawdopodobieństwo tego że podróżował samolotem nr 3
# P(A3) = 40 / (60+50+40) = 40/150 = 4/15

# %%
## B)
# Prawdopodobieństwo że zaginął mu bagaż
# P(B) = 1/10 * 60/150 + 2/10 * 50/150 + 3/10 * 40/150 = 6/150 + 10/150 + 12/150 = 28/150 = 14/75

# %%
## C)
# Prawdopodobieństwo że podróżował samolotem nr 3 pod warunkiem że zaginął mu bagaż
# P(B | A3) = 3/10
# P(A3|B) = P(B | A3) * P(A3) / P(B) = (3/10) * (4/15) / (14/75) = 2/25 / (14/75) = 3/7

# %% [markdown]
# ## ZAD. 9

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# P(Inspekcji) = 0.2
# P(~Inspekcji) = 0.8
# P(Defekt | Inspekcji) = 0.9
# P(Defekt | ~Inspekcji) = 0.7

# P(Inspekcji | Defekt) = P(Defekt | Inspekcji) * P(Inspekcji) / P(Defekt)
# P(Defekt) = P(Defelt | Inspekcji) * P(Inspekcji) + P(Defekt | ~Inspekcji) * P(~Inspekcji)
# P(Defekt) = 0.9 * 0.2 + 0.7 * 0.8 = 0.18 + 0.56 = 0.74

# P(Inspekcji | Defekt) = 0.9 * 0.2 / 0.74 = 0.18 / 0.74 => 24.32%
